# %%
import json

# Load data directly from file
arc_challenge_file = './input/arc-prize-shrink/arc-agi_test_challenges.json'


# Load original data
arc_data = None
with open(arc_challenge_file, 'r') as f:
    arc_data = json.load(f)

list(arc_data.items())[0]
# Out:
# ('00576224',
#  {'train': [{'input': [[7, 9], [4, 3]],
#     'output': [[7, 9, 7, 9, 7, 9],
#      [4, 3, 4, 3, 4, 3],
#      [9, 7, 9, 7, 9, 7],
#      [3, 4, 3, 4, 3, 4],
#      [7, 9, 7, 9, 7, 9],
#      [4, 3, 4, 3, 4, 3]]},
#    {'input': [[8, 6], [6, 4]],
#     'output': [[8, 6, 8, 6, 8, 6],
#      [6, 4, 6, 4, 6, 4],
#      [6, 8, 6, 8, 6, 8],
#      [4, 6, 4, 6, 4, 6],
#      [8, 6, 8, 6, 8, 6],
#      [6, 4, 6, 4, 6, 4]]}],
#   'test': [{'input': [[3, 2], [7, 8]]}]})

# %%
import arc_visualizer as ArcVisualizer

ArcVisualizer.init_from_file("./input/arc-prize/something.json")

ArcVisualizer.from_text("abcdefgI/10357882/12958")
ArcVisualizer.from_key("0157284")
